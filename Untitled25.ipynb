# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the uploaded training dataset
df = pd.read_csv('train_u6lujuX_CVtuZ9i.csv')

print(f"Dataset Shape: {df.shape}")
print("\nFirst 5 rows:")
display(df.head())

print("\nDataset Info:")
df.info()
# Out:
# Dataset Shape: (614, 13)
#
# First 5 rows:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Drop Loan_ID if present
if 'Loan_ID' in df.columns:
    df = df.drop(columns=['Loan_ID'])

# 1. Check missing values before imputation
print("Missing values before imputation:\n", df.isnull().sum())

# 2. Impute numerical columns with median and categorical with mode
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
cat_cols = df.select_dtypes(include=['object']).columns

for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# 3. Encode target variable (Loan_Status: Y -> 1, N -> 0)
df['Loan_Status'] = df['Loan_Status'].map({'Y': 1, 'N': 0})

# Separate features and target
X = df.drop(columns=['Loan_Status'])
y = df['Loan_Status']

# Convert categorical features using One-Hot Encoding
feature_cat_cols = X.select_dtypes(include=['object']).columns
X = pd.get_dummies(X, columns=feature_cat_cols, drop_first=True)

# 4. Split dataset: 80% train and 20% test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

# 5. Standardize features using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print("\nPreprocessing complete.")
print(f"X_train shape: {X_train_scaled.shape}")
print(f"X_test shape: {X_test_scaled.shape}")
# Out:
# Missing values before imputation:
#  Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64
#
# Preprocessing complete.
# X_train shape: (491, 14)
# X_test shape: (123, 14)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# 1. Default KNN model (n_neighbors=5)
knn_default = KNeighborsClassifier()
knn_default.fit(X_train_scaled, y_train)

y_pred_default = knn_default.predict(X_test_scaled)
acc_default = accuracy_score(y_test, y_pred_default)
print(f"Default KNN (k=5) Accuracy: {acc_default * 100:.2f}%\n")

# 2. Experiment with different k values
print("--- Experimenting with k values ---")
for k in [3, 5, 7, 9, 11]:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)
    acc = accuracy_score(y_test, knn.predict(X_test_scaled))
    print(f"Accuracy for k={k}: {acc * 100:.2f}%")
# Out:
# Default KNN (k=5) Accuracy: 83.74%
#
# --- Experimenting with k values ---
# Accuracy for k=3: 81.30%
# Accuracy for k=5: 83.74%
# Accuracy for k=7: 84.55%
# Accuracy for k=9: 82.11%
# Accuracy for k=11: 82.93%

# %%
from sklearn.model_selection import GridSearchCV

# Search parameter grid for n_neighbors
param_grid = {'n_neighbors': list(range(1, 25))}

grid_search = GridSearchCV(
    KNeighborsClassifier(),
    param_grid,
    cv=5,
    scoring='accuracy'
)
grid_search.fit(X_train_scaled, y_train)

best_knn = grid_search.best_estimator_
best_k = grid_search.best_params_['n_neighbors']

print(f"Best n_neighbors (k): {best_k}")
print(f"Best Cross-Validation Score: {grid_search.best_score_ * 100:.2f}%")
# Out:
# Best n_neighbors (k): 20
# Best Cross-Validation Score: 79.43%

# %%
from sklearn.metrics import confusion_matrix, classification_report

# Predictions with the tuned model
y_pred_tuned = best_knn.predict(X_test_scaled)
acc_tuned = accuracy_score(y_test, y_pred_tuned)

print("=" * 45)
print(f"Default KNN Accuracy: {acc_default * 100:.2f}%")
print(f"Tuned KNN Accuracy:   {acc_tuned * 100:.2f}%")
print("=" * 45)

print("\nClassification Report (Tuned KNN):")
print(classification_report(y_test, y_pred_tuned, target_names=['Rejected (0)', 'Approved (1)']))

# Side-by-side Confusion Matrix comparison
fig, axes = plt.subplots(1, 2, figsize=(13, 4.5))

cm_default = confusion_matrix(y_test, y_pred_default)
sns.heatmap(cm_default, annot=True, fmt='d', cmap='Blues', ax=axes[0],
            xticklabels=['Rejected', 'Approved'], yticklabels=['Rejected', 'Approved'])
axes[0].set_title(f"Default KNN (k=5)\nAccuracy: {acc_default * 100:.2f}%")
axes[0].set_xlabel("Predicted")
axes[0].set_ylabel("True")

cm_tuned = confusion_matrix(y_test, y_pred_tuned)
sns.heatmap(cm_tuned, annot=True, fmt='d', cmap='Greens', ax=axes[1],
            xticklabels=['Rejected', 'Approved'], yticklabels=['Rejected', 'Approved'])
axes[1].set_title(f"Tuned KNN (k={best_k})\nAccuracy: {acc_tuned * 100:.2f}%")
axes[1].set_xlabel("Predicted")
axes[1].set_ylabel("True")

plt.tight_layout()
plt.show()
# Out:
# ...
# Default KNN Accuracy: 83.74%
# Tuned KNN Accuracy:   81.30%
# ...
#
# Classification Report (Tuned KNN):
#               precision    recall  f1-score   support
#
# Rejected (0)       0.94      0.42      0.58        38
# Approved (1)       0.79      0.99      0.88        85
#
#     accuracy                           0.81       123
#    macro avg       0.87      0.70      0.73       123
# weighted avg       0.84      0.81      0.79       123
